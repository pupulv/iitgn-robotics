# %%
import numpy as np
import pandas as pd

from google.colab import files
uploaded = files.upload()

import io
df = pd.read_excel(io.BytesIO(uploaded['Gait_DATA.xlsx']))
# Out:
#      <input type="file" id="files-a1797cff-958d-42d0-b768-a8174c210237" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a1797cff-958d-42d0-b768-a8174c210237">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Gait_DATA.xlsx to Gait_DATA (2).xlsx

# %%
import io
import matplotlib.pyplot as plt
df = pd.read_excel("Gait_DATA.xlsx")
print(df)
x = list(df['X (cm)'])
y = list(df['Y (cm)'])
plt.figure(figsize=(10,10))
plt.style.use('seaborn')
plt.scatter(x,y,marker="*",s=100,edgecolors="black",c="yellow")
plt.title("Excel sheet to Scatter Plot")
plt.show()
# Out:
#         X (cm)     Y (cm)
# 0    46.108625  12.809129
# 1    45.628312  12.786217
# 2    45.105438  12.732817
# 3    44.568188  12.646511
# 4    44.005938  12.526861
# ..         ...        ...
# 256  49.286187   9.933923
# 257  49.174875  10.148979
# 258  49.047063  10.359342
# 259  48.911938  10.559667
# 260  46.108625  12.809129
#
# [261 rows x 2 columns]
